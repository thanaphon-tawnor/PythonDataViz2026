# %% [markdown]
# <a href="https://colab.research.google.com/github/thanaphon-tawnor/PythonDataViz2026/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ธนพล ท้าวนอ

# %%
print("673020253-2")
# Out:
# 673020253-2
